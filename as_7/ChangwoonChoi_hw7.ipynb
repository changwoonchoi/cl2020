# %% [markdown]
# M2780.002400 Machine Listening (Fall 2020)
#
# Instructor: Kyogu Lee (kglee@snu.ac.kr)

# %% [markdown]
# # Assignment 7: Improving Machine Learning
#
# (85 points)
#
# Due Date : This assignment is due by 12:59PM, November 10 (Tuesday)
#
#
# ---
#
# Assignment
#
# This assignment is composed of two parts: Theory and Lab assignments, you will need to write the answers for the Theory problems and Notebook scripts and/or functions as required. Submit them electronically (via **ETL**) by the end of the due date.

# %% [markdown]
# # Theory (45pts)

# %% [markdown]
# ---
#
# 1.   Bias and Variance, Regularization  (10 pts)
#
# Suppose you are using Ridge Regression and you notice that the training error
# and the validation error are almost equal and fairly high. Would you say that the
# model suffers from high bias or high variance? Should you increase the regularization
# hyperparameter α or reduce it?

# %% [markdown]
# ---
#
# 2.   Regularization  (10 pts)
#
# Suppose you are using Polynomial Regression. You plot the learning curves and
# you notice that there is a large gap between the training error and the validation
# error. What is happening? What are three ways to solve this?

# %% [markdown]
# ---
#
# 3. Dropout (10 pts)
#
#  a. Explain the dropout technique in terms of the dropout rate *p*.
#
#  b. Does dropout slow down training? Does it slow down inference (i.e., making
# predictions on new instances)?

# %% [markdown]
# ---
#
# 4. Optimization (15 pts)
#
# State the *True* or *False* for the followings.
#
#   a. Adam should be used with batch gradient computations, not with mini-batches.
#
#   b. Adam combines the advantages of RMSProp and gradient descent with momentum.
#
#   c. The learning rate of the Adam optimizer does not need to be tuned.

# %% [markdown]
# # Lab (40pts)

# %% [markdown]
# For all lab assignments, submit your Notebook file (.ipynb) and audio files (.wav) with one compressed (.zip) file, via **ETL**. The Notebook file and zip file should be named with your full name and the homework number – e.g., ***아무개_hw7.ipynb, 아무개_hw7.zip***
#
# In addition to writing Python scripts and/or functions in your Notebook file, there are also questions you’ll have to answer. For such questions, you should provide answers in your Notebook file using Text sections.
#
# **Please submit the codes executed (make sure that the results of your codes are visible in the submitted assignments) so that the grader can check whether the code is working or not.**

# %%
import numpy as np
from matplotlib import pyplot as plt

import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential 
from keras.layers import Dense, Activation, BatchNormalization
from keras.regularizers import l1, l2
from keras.utils import np_utils

from sklearn.metrics import classification_report, confusion_matrix
import itertools


'''
config = tf.compat.v1.ConfigProto(device_count = {'GPU': 0 , 'CPU': 8})
sess = tf.compat.v1.Session(config=config) 
keras.backend.set_session(sess)
'''
# Out:
# "\nconfig = tf.compat.v1.ConfigProto(device_count = {'GPU': 0 , 'CPU': 8})\nsess = tf.compat.v1.Session(config=config) \nkeras.backend.set_session(sess)\n"

# %% [markdown]
# ---
#
# 1.   MNIST using keras with L1, L2 regularization  (10 pts)
#
# Refer to the lab6 and Keras tutorials to create and learn a neural network that classifies MNIST handwriting data and organize the results using keras. Use the best model you created at problem 3 on assignment6. Implement l1 and l2 regularization on the loss function using keras.regularizers. Compare the results of three models, with no regularization, with L1 regularization, and L2 regularization using accuracy and confusion matrix.

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
classes = 10
Y_train = np_utils.to_categorical(Y_train, classes)
Y_test = np_utils.to_categorical(Y_test, classes)

# %%
batch_size = 256
epochs = 100

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10

model = Sequential()
model.add(Dense(nn_hdim_1, input_dim=input_dim))
model.add(Activation('relu'))
model.add(Dense(nn_hdim_2))
model.add(Activation('relu'))
model.add(Dense(nn_hdim_3))
model.add(Activation('relu'))
model.add(Dense(output_dim))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', 
              metrics=['accuracy'], optimizer='adadelta')

# %%
model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.2877 - accuracy: 0.1044
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.1900 - accuracy: 0.2409
# Epoch 3/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.0891 - accuracy: 0.4224
# Epoch 4/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.9794 - accuracy: 0.5521
# Epoch 5/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.8617 - accuracy: 0.6260
# Epoch 6/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.7387 - accuracy: 0.6760
# Epoch 7/100
# 235/235 [==============================] - 2s 6ms/step - loss: 1.6132 - accuracy: 0.7178
# Epoch 8/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.4891 - accuracy: 0.7484
# Epoch 9/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.3711 - accuracy: 0.7707
# Epoch 10/100
# 235/235 [==============================] - 2s 6ms/step - loss: 1.2617 - accuracy: 0.7894
# Epoch 11/100
# 235/235 [==============================] - 2s 6ms/step - loss: 1.1622 - accuracy: 0.8036
# Epoch 12/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.0736 - accuracy: 0.8145
# Epoch 13/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.9953 - accuracy: 0.8231
# Epoch 14/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.9269 - accuracy: 0.8293
# Epoch 15/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.8675 - accuracy: 0.8351
# Epoch 16/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.8161 - accuracy: 0.8409
# Epoch 17/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.7714 - accuracy: 0.8452
# Epoch 18/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.7324 - accuracy: 0.8493
# Epoch 19/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.6981 - accuracy: 0.8532
# Epoch 20/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6679 - accuracy: 0.8567
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.6411 - accuracy: 0.8599
# Epoch 22/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6172 - accuracy: 0.8630
# Epoch 23/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5958 - accuracy: 0.8658
# Epoch 24/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5766 - accuracy: 0.8687
# Epoch 25/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.5591 - accuracy: 0.8709
# Epoch 26/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5432 - accuracy: 0.8731
# Epoch 27/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5286 - accuracy: 0.8752
# Epoch 28/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5153 - accuracy: 0.8772
# Epoch 29/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5031 - accuracy: 0.8791
# Epoch 30/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4917 - accuracy: 0.8809
# Epoch 31/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4812 - accuracy: 0.8826
# Epoch 32/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4715 - accuracy: 0.8844
# Epoch 33/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4624 - accuracy: 0.8859
# Epoch 34/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4540 - accuracy: 0.8877
# Epoch 35/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4461 - accuracy: 0.8889
# Epoch 36/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4386 - accuracy: 0.8899
# Epoch 37/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4316 - accuracy: 0.8909
# Epoch 38/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4251 - accuracy: 0.8922
# Epoch 39/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4189 - accuracy: 0.8933
# Epoch 40/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4130 - accuracy: 0.8942
# Epoch 41/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4074 - accuracy: 0.8954
# Epoch 42/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4021 - accuracy: 0.8962
# Epoch 43/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3972 - accuracy: 0.8971
# Epoch 44/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3924 - accuracy: 0.8980
# Epoch 45/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3879 - accuracy: 0.8989
# Epoch 46/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3836 - accuracy: 0.8995
# Epoch 47/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3794 - accuracy: 0.9004
# Epoch 48/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3754 - accuracy: 0.9013
# Epoch 49/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3716 - accuracy: 0.9021
# Epoch 50/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3680 - accuracy: 0.9027
# Epoch 51/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3644 - accuracy: 0.9037
# Epoch 52/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3610 - accuracy: 0.9042
# Epoch 53/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3578 - accuracy: 0.9047
# Epoch 54/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3547 - accuracy: 0.9055
# Epoch 55/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3516 - accuracy: 0.9061
# Epoch 56/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3487 - accuracy: 0.9066
# Epoch 57/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3459 - accuracy: 0.9072
# Epoch 58/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3431 - accuracy: 0.9077
# Epoch 59/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3405 - accuracy: 0.9085
# Epoch 60/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3379 - accuracy: 0.9088
# Epoch 61/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3354 - accuracy: 0.9093
# Epoch 62/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3330 - accuracy: 0.9097
# Epoch 63/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3306 - accuracy: 0.9104
# Epoch 64/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3284 - accuracy: 0.9105
# Epoch 65/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3261 - accuracy: 0.9110
# Epoch 66/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3240 - accuracy: 0.9115
# Epoch 67/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3219 - accuracy: 0.9120
# Epoch 68/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3198 - accuracy: 0.9124
# Epoch 69/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3179 - accuracy: 0.9127
# Epoch 70/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3159 - accuracy: 0.9132
# Epoch 71/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3140 - accuracy: 0.9137
# Epoch 72/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3122 - accuracy: 0.9142
# Epoch 73/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3103 - accuracy: 0.9148
# Epoch 74/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3086 - accuracy: 0.9151
# Epoch 75/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3068 - accuracy: 0.9155
# Epoch 76/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3052 - accuracy: 0.9160
# Epoch 77/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3035 - accuracy: 0.9163
# Epoch 78/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3019 - accuracy: 0.9168
# Epoch 79/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3003 - accuracy: 0.9171
# Epoch 80/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2988 - accuracy: 0.9174
# Epoch 81/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2972 - accuracy: 0.9177
# Epoch 82/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2957 - accuracy: 0.9183
# Epoch 83/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2943 - accuracy: 0.9186
# Epoch 84/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2928 - accuracy: 0.9188
# Epoch 85/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2914 - accuracy: 0.9192
# Epoch 86/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2900 - accuracy: 0.9195
# Epoch 87/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2887 - accuracy: 0.9199
# Epoch 88/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2873 - accuracy: 0.9201
# Epoch 89/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2860 - accuracy: 0.9204
# Epoch 90/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2847 - accuracy: 0.9208
# Epoch 91/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2834 - accuracy: 0.9212
# Epoch 92/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2822 - accuracy: 0.9215
# Epoch 93/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2809 - accuracy: 0.9218
# Epoch 94/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2797 - accuracy: 0.9220
# Epoch 95/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2785 - accuracy: 0.9225
# Epoch 96/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2774 - accuracy: 0.9225
# Epoch 97/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2762 - accuracy: 0.9228
# Epoch 98/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2750 - accuracy: 0.9230
# Epoch 99/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2739 - accuracy: 0.9233
# Epoch 100/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2728 - accuracy: 0.9238

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 905us/step - loss: 0.2630 - accuracy: 0.9280
#
# Test accuracy: 0.9279999732971191

# %%
Y_pred_vanilla = model.predict(X_test)
y_pred_vanilla = np.argmax(Y_pred_vanilla, axis=1)
y_gt = np.argmax(Y_test, axis=1)

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_vanilla)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of vanilla model")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10
model_l1 = Sequential()
# model_l1.add(Dense(nn_hdim_1, input_dim=input_dim, ))
model_l1.add(Dense(nn_hdim_1, kernel_regularizer=l1(0.001), input_dim=784))
model_l1.add(Activation('relu'))
model_l1.add(Dense(nn_hdim_2, kernel_regularizer=l1(0.001)))
model_l1.add(Activation('relu'))
model_l1.add(Dense(nn_hdim_3, kernel_regularizer=l1(0.001)))
model_l1.add(Activation('relu'))
model_l1.add(Dense(output_dim, kernel_regularizer=l1(0.001)))
model_l1.add(Activation('softmax'))

model_l1.compile(loss='categorical_crossentropy', 
                 metrics=['accuracy'], optimizer='adadelta')

# %%
print(X_train.shape)
model_l1.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# (60000, 784)
# Epoch 1/100
# 235/235 [==============================] - 2s 9ms/step - loss: 44.9532 - accuracy: 0.1416
# Epoch 2/100
# 235/235 [==============================] - 2s 9ms/step - loss: 44.6092 - accuracy: 0.2713
# Epoch 3/100
# 235/235 [==============================] - 2s 9ms/step - loss: 44.2500 - accuracy: 0.4056
# Epoch 4/100
# 235/235 [==============================] - 2s 8ms/step - loss: 43.8804 - accuracy: 0.5101
# Epoch 5/100
# 235/235 [==============================] - 2s 8ms/step - loss: 43.5019 - accuracy: 0.5838
# Epoch 6/100
# 235/235 [==============================] - 2s 8ms/step - loss: 43.1168 - accuracy: 0.6287
# Epoch 7/100
# 235/235 [==============================] - 2s 9ms/step - loss: 42.7285 - accuracy: 0.6634
# Epoch 8/100
# 235/235 [==============================] - 2s 9ms/step - loss: 42.3411 - accuracy: 0.6931
# Epoch 9/100
# 235/235 [==============================] - 2s 8ms/step - loss: 41.9584 - accuracy: 0.7185
# Epoch 10/100
# 235/235 [==============================] - 2s 8ms/step - loss: 41.5826 - accuracy: 0.7387
# Epoch 11/100
# 235/235 [==============================] - 2s 8ms/step - loss: 41.2152 - accuracy: 0.7553
# Epoch 12/100
# 235/235 [==============================] - 2s 9ms/step - loss: 40.8567 - accuracy: 0.7702
# Epoch 13/100
# 235/235 [==============================] - 2s 9ms/step - loss: 40.5068 - accuracy: 0.7812
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 40.1653 - accuracy: 0.7919
# Epoch 15/100
# 235/235 [==============================] - 2s 9ms/step - loss: 39.8320 - accuracy: 0.7999
# Epoch 16/100
# 235/235 [==============================] - 2s 9ms/step - loss: 39.5063 - accuracy: 0.8082
# Epoch 17/100
# 235/235 [==============================] - 2s 9ms/step - loss: 39.1875 - accuracy: 0.8160
# Epoch 18/100
# 235/235 [==============================] - 2s 9ms/step - loss: 38.8749 - accuracy: 0.8219
# Epoch 19/100
# 235/235 [==============================] - 2s 9ms/step - loss: 38.5681 - accuracy: 0.8279
# Epoch 20/100
# 235/235 [==============================] - 2s 9ms/step - loss: 38.2661 - accuracy: 0.8326
# Epoch 21/100
# 235/235 [==============================] - 2s 9ms/step - loss: 37.9687 - accuracy: 0.8373
# Epoch 22/100
# 235/235 [==============================] - 2s 9ms/step - loss: 37.6752 - accuracy: 0.8414
# Epoch 23/100
# 235/235 [==============================] - 2s 9ms/step - loss: 37.3853 - accuracy: 0.8445
# Epoch 24/100
# 235/235 [==============================] - 2s 9ms/step - loss: 37.0989 - accuracy: 0.8479
# Epoch 25/100
# 235/235 [==============================] - 2s 9ms/step - loss: 36.8158 - accuracy: 0.8508
# Epoch 26/100
# 235/235 [==============================] - 2s 9ms/step - loss: 36.5356 - accuracy: 0.8536
# Epoch 27/100
# 235/235 [==============================] - 2s 9ms/step - loss: 36.2579 - accuracy: 0.8562
# Epoch 28/100
# 235/235 [==============================] - 2s 9ms/step - loss: 35.9825 - accuracy: 0.8583
# Epoch 29/100
# 235/235 [==============================] - 2s 9ms/step - loss: 35.7091 - accuracy: 0.8608
# Epoch 30/100
# 235/235 [==============================] - 2s 9ms/step - loss: 35.4380 - accuracy: 0.8628
# Epoch 31/100
# 235/235 [==============================] - 2s 9ms/step - loss: 35.1688 - accuracy: 0.8647
# Epoch 32/100
# 235/235 [==============================] - 2s 9ms/step - loss: 34.9015 - accuracy: 0.8664
# Epoch 33/100
# 235/235 [==============================] - 2s 9ms/step - loss: 34.6361 - accuracy: 0.8681
# Epoch 34/100
# 235/235 [==============================] - 2s 9ms/step - loss: 34.3726 - accuracy: 0.8698
# Epoch 35/100
# 235/235 [==============================] - 2s 9ms/step - loss: 34.1107 - accuracy: 0.8716
# Epoch 36/100
# 235/235 [==============================] - 2s 9ms/step - loss: 33.8505 - accuracy: 0.8724
# Epoch 37/100
# 235/235 [==============================] - 2s 9ms/step - loss: 33.5919 - accuracy: 0.8735
# Epoch 38/100
# 235/235 [==============================] - 2s 9ms/step - loss: 33.3347 - accuracy: 0.8746
# Epoch 39/100
# 235/235 [==============================] - 2s 9ms/step - loss: 33.0789 - accuracy: 0.8760
# Epoch 40/100
# 235/235 [==============================] - 2s 9ms/step - loss: 32.8245 - accuracy: 0.8774
# Epoch 41/100
# 235/235 [==============================] - 2s 9ms/step - loss: 32.5715 - accuracy: 0.8783
# Epoch 42/100
# 235/235 [==============================] - 2s 9ms/step - loss: 32.3198 - accuracy: 0.8793
# Epoch 43/100
# 235/235 [==============================] - 2s 9ms/step - loss: 32.0694 - accuracy: 0.8802
# Epoch 44/100
# 235/235 [==============================] - 2s 9ms/step - loss: 31.8202 - accuracy: 0.8809
# Epoch 45/100
# 235/235 [==============================] - 2s 9ms/step - loss: 31.5726 - accuracy: 0.8820
# Epoch 46/100
# 235/235 [==============================] - 2s 9ms/step - loss: 31.3261 - accuracy: 0.8826
# Epoch 47/100
# 235/235 [==============================] - 2s 9ms/step - loss: 31.0812 - accuracy: 0.8835
# Epoch 48/100
# 235/235 [==============================] - 2s 9ms/step - loss: 30.8372 - accuracy: 0.8845
# Epoch 49/100
# 235/235 [==============================] - 2s 9ms/step - loss: 30.5945 - accuracy: 0.8851
# Epoch 50/100
# 235/235 [==============================] - 2s 9ms/step - loss: 30.3527 - accuracy: 0.8857
# Epoch 51/100
# 235/235 [==============================] - 2s 9ms/step - loss: 30.1123 - accuracy: 0.8864
# Epoch 52/100
# 235/235 [==============================] - 2s 9ms/step - loss: 29.8730 - accuracy: 0.8870
# Epoch 53/100
# 235/235 [==============================] - 2s 9ms/step - loss: 29.6351 - accuracy: 0.8877
# Epoch 54/100
# 235/235 [==============================] - 2s 9ms/step - loss: 29.3982 - accuracy: 0.8885
# Epoch 55/100
# 235/235 [==============================] - 2s 9ms/step - loss: 29.1624 - accuracy: 0.8888
# Epoch 56/100
# 235/235 [==============================] - 2s 9ms/step - loss: 28.9278 - accuracy: 0.8894
# Epoch 57/100
# 235/235 [==============================] - 2s 9ms/step - loss: 28.6943 - accuracy: 0.8899
# Epoch 58/100
# 235/235 [==============================] - 2s 9ms/step - loss: 28.4619 - accuracy: 0.8902
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 28.2307 - accuracy: 0.8909
# Epoch 60/100
# 235/235 [==============================] - 2s 9ms/step - loss: 28.0007 - accuracy: 0.8911
# Epoch 61/100
# 235/235 [==============================] - 2s 9ms/step - loss: 27.7718 - accuracy: 0.8915
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 27.5439 - accuracy: 0.8918
# Epoch 63/100
# 235/235 [==============================] - 2s 9ms/step - loss: 27.3171 - accuracy: 0.8922
# Epoch 64/100
# 235/235 [==============================] - 2s 8ms/step - loss: 27.0917 - accuracy: 0.8927
# Epoch 65/100
# 235/235 [==============================] - 2s 9ms/step - loss: 26.8672 - accuracy: 0.8926
# Epoch 66/100
# 235/235 [==============================] - 2s 9ms/step - loss: 26.6436 - accuracy: 0.8928
# Epoch 67/100
# 235/235 [==============================] - 2s 9ms/step - loss: 26.4211 - accuracy: 0.8931
# Epoch 68/100
# 235/235 [==============================] - 2s 9ms/step - loss: 26.1998 - accuracy: 0.8935
# Epoch 69/100
# 235/235 [==============================] - 2s 9ms/step - loss: 25.9796 - accuracy: 0.8938
# Epoch 70/100
# 235/235 [==============================] - 2s 9ms/step - loss: 25.7604 - accuracy: 0.8941
# Epoch 71/100
# 235/235 [==============================] - 2s 9ms/step - loss: 25.5424 - accuracy: 0.8942
# Epoch 72/100
# 235/235 [==============================] - 2s 9ms/step - loss: 25.3257 - accuracy: 0.8948
# Epoch 73/100
# 235/235 [==============================] - 2s 9ms/step - loss: 25.1097 - accuracy: 0.8949
# Epoch 74/100
# 235/235 [==============================] - 2s 9ms/step - loss: 24.8948 - accuracy: 0.8947A: 1
# Epoch 75/100
# 235/235 [==============================] - 2s 9ms/step - loss: 24.6811 - accuracy: 0.8952
# Epoch 76/100
# 235/235 [==============================] - 2s 9ms/step - loss: 24.4684 - accuracy: 0.8953
# Epoch 77/100
# 235/235 [==============================] - 2s 9ms/step - loss: 24.2568 - accuracy: 0.8957
# Epoch 78/100
# 235/235 [==============================] - 2s 9ms/step - loss: 24.0464 - accuracy: 0.8960
# Epoch 79/100
# 235/235 [==============================] - 2s 9ms/step - loss: 23.8371 - accuracy: 0.8960
# Epoch 80/100
# 235/235 [==============================] - 2s 9ms/step - loss: 23.6289 - accuracy: 0.8960
# Epoch 81/100
# 235/235 [==============================] - 2s 9ms/step - loss: 23.4217 - accuracy: 0.8964
# Epoch 82/100
# 235/235 [==============================] - 2s 9ms/step - loss: 23.2159 - accuracy: 0.8965
# Epoch 83/100
# 235/235 [==============================] - 2s 9ms/step - loss: 23.0112 - accuracy: 0.8968
# Epoch 84/100
# 235/235 [==============================] - 2s 9ms/step - loss: 22.8075 - accuracy: 0.8967
# Epoch 85/100
# 235/235 [==============================] - 2s 9ms/step - loss: 22.6048 - accuracy: 0.8971
# Epoch 86/100
# 235/235 [==============================] - 2s 9ms/step - loss: 22.4032 - accuracy: 0.8971
# Epoch 87/100
# 235/235 [==============================] - 2s 9ms/step - loss: 22.2027 - accuracy: 0.8974
# Epoch 88/100
# 235/235 [==============================] - 2s 9ms/step - loss: 22.0033 - accuracy: 0.8977
# Epoch 89/100
# 235/235 [==============================] - 2s 8ms/step - loss: 21.8047 - accuracy: 0.8976
# Epoch 90/100
# 235/235 [==============================] - 2s 9ms/step - loss: 21.6071 - accuracy: 0.8978
# Epoch 91/100
# 235/235 [==============================] - 2s 8ms/step - loss: 21.4107 - accuracy: 0.8977
# Epoch 92/100
# 235/235 [==============================] - 2s 8ms/step - loss: 21.2155 - accuracy: 0.8981
# Epoch 93/100
# 235/235 [==============================] - 2s 9ms/step - loss: 21.0215 - accuracy: 0.8982
# Epoch 94/100
# 235/235 [==============================] - 2s 9ms/step - loss: 20.8287 - accuracy: 0.8982
# Epoch 95/100
# 235/235 [==============================] - 2s 9ms/step - loss: 20.6369 - accuracy: 0.8984
# Epoch 96/100
# 235/235 [==============================] - 2s 9ms/step - loss: 20.4462 - accuracy: 0.8985
# Epoch 97/100
# 235/235 [==============================] - 2s 9ms/step - loss: 20.2566 - accuracy: 0.8986
# Epoch 98/100
# 235/235 [==============================] - 2s 9ms/step - loss: 20.0679 - accuracy: 0.8985
# Epoch 99/100
# 235/235 [==============================] - 2s 9ms/step - loss: 19.8802 - accuracy: 0.8986
# Epoch 100/100
# 235/235 [==============================] - 2s 9ms/step - loss: 19.6937 - accuracy: 0.8986

# %%
score = model_l1.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 19.5811 - accuracy: 0.9050
#
# Test accuracy: 0.9049999713897705

# %%
Y_pred_l1 = model_l1.predict(X_test)
y_pred_l1 = np.argmax(Y_pred_l1, axis=1)
y_gt = np.argmax(Y_test, axis=1)

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_l1)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with l1 regularizer")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10

model_l2 = Sequential()
model_l2.add(Dense(nn_hdim_1, kernel_regularizer=l2(0.001), input_dim=784))
model.add(Activation('relu'))
model_l2.add(Dense(nn_hdim_2, kernel_regularizer=l2(0.001)))
model.add(Activation('relu'))
model_l2.add(Dense(nn_hdim_3, kernel_regularizer=l2(0.001)))
model.add(Activation('relu'))
model_l2.add(Dense(output_dim, kernel_regularizer=l2(0.001)))
model_l2.add(Activation('softmax'))

model_l2.compile(loss='categorical_crossentropy', 
                 metrics=['accuracy'], optimizer='adadelta')

# %%
print(X_train.shape)
model_l2.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# (60000, 784)
# Epoch 1/100
# 235/235 [==============================] - 2s 8ms/step - loss: 3.9483 - accuracy: 0.2489
# Epoch 2/100
# 235/235 [==============================] - 2s 8ms/step - loss: 3.4473 - accuracy: 0.5676
# Epoch 3/100
# 235/235 [==============================] - 2s 8ms/step - loss: 3.1063 - accuracy: 0.7050
# Epoch 4/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.8773 - accuracy: 0.7600
# Epoch 5/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.7206 - accuracy: 0.7915
# Epoch 6/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.6102 - accuracy: 0.8120
# Epoch 7/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.5300 - accuracy: 0.8271
# Epoch 8/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.4696 - accuracy: 0.8375
# Epoch 9/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.4230 - accuracy: 0.8459
# Epoch 10/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3858 - accuracy: 0.8518
# Epoch 11/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3557 - accuracy: 0.8569
# Epoch 12/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3307 - accuracy: 0.8618
# Epoch 13/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3097 - accuracy: 0.8655
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2915 - accuracy: 0.8687
# Epoch 15/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2756 - accuracy: 0.8715
# Epoch 16/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2617 - accuracy: 0.8740
# Epoch 17/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2493 - accuracy: 0.8758
# Epoch 18/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2382 - accuracy: 0.8781
# Epoch 19/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2281 - accuracy: 0.8798
# Epoch 20/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2189 - accuracy: 0.8813
# Epoch 21/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2105 - accuracy: 0.8827
# Epoch 22/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2028 - accuracy: 0.8843
# Epoch 23/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1956 - accuracy: 0.8854
# Epoch 24/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1889 - accuracy: 0.8867
# Epoch 25/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1826 - accuracy: 0.8878
# Epoch 26/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.1767 - accuracy: 0.8887
# Epoch 27/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1712 - accuracy: 0.8898
# Epoch 28/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1659 - accuracy: 0.8904
# Epoch 29/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1609 - accuracy: 0.8913
# Epoch 30/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1562 - accuracy: 0.8918
# Epoch 31/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1517 - accuracy: 0.8926
# Epoch 32/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1473 - accuracy: 0.8933
# Epoch 33/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1432 - accuracy: 0.8936
# Epoch 34/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1392 - accuracy: 0.8942
# Epoch 35/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1353 - accuracy: 0.8949
# Epoch 36/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1316 - accuracy: 0.8957
# Epoch 37/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1280 - accuracy: 0.8967
# Epoch 38/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1245 - accuracy: 0.8974
# Epoch 39/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1211 - accuracy: 0.8976
# Epoch 40/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1178 - accuracy: 0.8979
# Epoch 41/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.1146 - accuracy: 0.8985
# Epoch 42/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1115 - accuracy: 0.8989
# Epoch 43/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1085 - accuracy: 0.8995
# Epoch 44/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1055 - accuracy: 0.9000
# Epoch 45/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1026 - accuracy: 0.9004
# Epoch 46/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0998 - accuracy: 0.9009
# Epoch 47/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0970 - accuracy: 0.9013
# Epoch 48/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0943 - accuracy: 0.9017
# Epoch 49/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0916 - accuracy: 0.9022
# Epoch 50/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0890 - accuracy: 0.9024
# Epoch 51/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0864 - accuracy: 0.9026
# Epoch 52/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0839 - accuracy: 0.9030
# Epoch 53/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0814 - accuracy: 0.9032
# Epoch 54/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0789 - accuracy: 0.9039
# Epoch 55/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0765 - accuracy: 0.9040
# Epoch 56/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0742 - accuracy: 0.9041
# Epoch 57/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0718 - accuracy: 0.9046
# Epoch 58/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0695 - accuracy: 0.9048
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0672 - accuracy: 0.9051
# Epoch 60/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0650 - accuracy: 0.9053
# Epoch 61/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0628 - accuracy: 0.9054
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0606 - accuracy: 0.9057
# Epoch 63/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0584 - accuracy: 0.9058
# Epoch 64/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0562 - accuracy: 0.9061
# Epoch 65/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0541 - accuracy: 0.9065
# Epoch 66/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0520 - accuracy: 0.9065
# Epoch 67/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0499 - accuracy: 0.9067
# Epoch 68/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0479 - accuracy: 0.9067
# Epoch 69/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0458 - accuracy: 0.9069
# Epoch 70/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0438 - accuracy: 0.9074
# Epoch 71/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0418 - accuracy: 0.9073
# Epoch 72/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0398 - accuracy: 0.9075
# Epoch 73/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0378 - accuracy: 0.9076
# Epoch 74/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0358 - accuracy: 0.9078
# Epoch 75/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0339 - accuracy: 0.9080
# Epoch 76/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0320 - accuracy: 0.9082
# Epoch 77/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0301 - accuracy: 0.9085
# Epoch 78/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0282 - accuracy: 0.9087
# Epoch 79/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0263 - accuracy: 0.9090
# Epoch 80/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0244 - accuracy: 0.9090
# Epoch 81/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0225 - accuracy: 0.9093
# Epoch 82/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0207 - accuracy: 0.9095
# Epoch 83/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0189 - accuracy: 0.9097
# Epoch 84/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0170 - accuracy: 0.9099
# Epoch 85/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0152 - accuracy: 0.9101
# Epoch 86/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0134 - accuracy: 0.9102
# Epoch 87/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0116 - accuracy: 0.9104
# Epoch 88/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0098 - accuracy: 0.9105
# Epoch 89/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0080 - accuracy: 0.9106
# Epoch 90/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0063 - accuracy: 0.9107
# Epoch 91/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0045 - accuracy: 0.9108
# Epoch 92/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0028 - accuracy: 0.9109
# Epoch 93/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0010 - accuracy: 0.9111
# Epoch 94/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9993 - accuracy: 0.9113
# Epoch 95/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9976 - accuracy: 0.9112
# Epoch 96/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9959 - accuracy: 0.9117
# Epoch 97/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9942 - accuracy: 0.9116
# Epoch 98/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9925 - accuracy: 0.9118
# Epoch 99/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9908 - accuracy: 0.9119
# Epoch 100/100
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9891 - accuracy: 0.9122

# %%
score = model_l2.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9775 - accuracy: 0.9159
#
# Test accuracy: 0.9158999919891357

# %%
Y_pred_l2 = model_l2.predict(X_test)
y_pred_l2 = np.argmax(Y_pred_l2, axis=1)
y_gt = np.argmax(Y_test, axis=1)

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_l2)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with l2 regularizer")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()

# %% [markdown]
# ## Summary

# %%
score_vanilla = model.evaluate(X_test, Y_test, verbose=1)
score_l1 = model_l1.evaluate(X_test, Y_test, verbose=1)
score_l2 = model_l2.evaluate(X_test, Y_test, verbose=1)

print('\n''Test accuracy of vanilla model:', score_vanilla[1])
print('\n''Test accuracy of model with l1 regularizer:', score_l1[1])
print('\n''Test accuracy of model with l2 regularizer:', score_l2[1])


plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_vanilla)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of vanilla model")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_l1)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with l1 regularizer")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_l2)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with l2 regularizer")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf
# Out:
# 313/313 [==============================] - 0s 894us/step - loss: 0.2630 - accuracy: 0.9280
# 313/313 [==============================] - 1s 2ms/step - loss: 19.5811 - accuracy: 0.9050
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9775 - accuracy: 0.9159
#
# Test accuracy of vanilla model: 0.9279999732971191
#
# Test accuracy of model with l1 regularizer: 0.9049999713897705
#
# Test accuracy of model with l2 regularizer: 0.9158999919891357
# <function matplotlib.pyplot.clf()>

# %% [markdown]
# ---
#
#
# 2.   MNIST using keras with batch normalization  (10 pts)
#
#
# Refer to the lab6 and Keras tutorials  to create and learn a neural network that classifies MNIST handwriting data and organize the results using keras. Use the best model you created at problem 3 on assignment6. Implement barch normalization on two of your hidden layers using keras.layers.BatchNormalization. Compare the results of two models, with batch normalizaion and without batch normalization using accuracy and confusion matrix.

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10
model_bn = Sequential()
# model_l1.add(Dense(nn_hdim_1, input_dim=input_dim, ))
model_bn.add(Dense(nn_hdim_1, input_dim=784))
model.add(BatchNormalization())
model.add(Activation('relu'))
model_bn.add(Dense(nn_hdim_2))
model.add(BatchNormalization())
model.add(Activation('relu'))
model_bn.add(Dense(nn_hdim_3))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model_bn.add(Dense(output_dim))
model_bn.add(Activation('softmax'))

model_bn.compile(loss='categorical_crossentropy', 
                 metrics=['accuracy'], optimizer='adadelta')

# %%
model_bn.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.1354 - accuracy: 0.2322
# Epoch 2/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.6698 - accuracy: 0.5780
# Epoch 3/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.3459 - accuracy: 0.6956
# Epoch 4/100
# 235/235 [==============================] - 2s 6ms/step - loss: 1.1207 - accuracy: 0.7509
# Epoch 5/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.9630 - accuracy: 0.7852
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.8504 - accuracy: 0.8059
# Epoch 7/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.7679 - accuracy: 0.8212
# Epoch 8/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.7056 - accuracy: 0.8319
# Epoch 9/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6573 - accuracy: 0.8416
# Epoch 10/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6190 - accuracy: 0.8481
# Epoch 11/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5881 - accuracy: 0.8536
# Epoch 12/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5624 - accuracy: 0.8582
# Epoch 13/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5409 - accuracy: 0.8617
# Epoch 14/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5226 - accuracy: 0.8648
# Epoch 15/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5068 - accuracy: 0.8677
# Epoch 16/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4930 - accuracy: 0.8704
# Epoch 17/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4809 - accuracy: 0.8726
# Epoch 18/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4701 - accuracy: 0.8751
# Epoch 19/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4605 - accuracy: 0.8773
# Epoch 20/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4518 - accuracy: 0.8788
# Epoch 21/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4439 - accuracy: 0.8805
# Epoch 22/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4369 - accuracy: 0.8820
# Epoch 23/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4303 - accuracy: 0.8839
# Epoch 24/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4243 - accuracy: 0.8852
# Epoch 25/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4187 - accuracy: 0.8864
# Epoch 26/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4136 - accuracy: 0.8876
# Epoch 27/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4089 - accuracy: 0.8882
# Epoch 28/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4045 - accuracy: 0.8893
# Epoch 29/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4003 - accuracy: 0.8902
# Epoch 30/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3965 - accuracy: 0.8909
# Epoch 31/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3928 - accuracy: 0.8920
# Epoch 32/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3894 - accuracy: 0.8926
# Epoch 33/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3861 - accuracy: 0.8933
# Epoch 34/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3831 - accuracy: 0.8941
# Epoch 35/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3802 - accuracy: 0.8949
# Epoch 36/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3774 - accuracy: 0.8957
# Epoch 37/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3748 - accuracy: 0.8964
# Epoch 38/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3723 - accuracy: 0.8968
# Epoch 39/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3700 - accuracy: 0.8975
# Epoch 40/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3677 - accuracy: 0.8978
# Epoch 41/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3655 - accuracy: 0.8984
# Epoch 42/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3634 - accuracy: 0.8987
# Epoch 43/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3614 - accuracy: 0.8992
# Epoch 44/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3596 - accuracy: 0.8997
# Epoch 45/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3577 - accuracy: 0.9000
# Epoch 46/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3560 - accuracy: 0.9005
# Epoch 47/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3543 - accuracy: 0.9007
# Epoch 48/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3527 - accuracy: 0.9013
# Epoch 49/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3511 - accuracy: 0.9016
# Epoch 50/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3496 - accuracy: 0.9018
# Epoch 51/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3482 - accuracy: 0.9023
# Epoch 52/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3467 - accuracy: 0.9028
# Epoch 53/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3454 - accuracy: 0.9032
# Epoch 54/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3441 - accuracy: 0.9035
# Epoch 55/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3428 - accuracy: 0.9038
# Epoch 56/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3416 - accuracy: 0.9040
# Epoch 57/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3404 - accuracy: 0.9044
# Epoch 58/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3392 - accuracy: 0.9045
# Epoch 59/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3381 - accuracy: 0.9048
# Epoch 60/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3370 - accuracy: 0.9053
# Epoch 61/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3359 - accuracy: 0.9054
# Epoch 62/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3349 - accuracy: 0.9057
# Epoch 63/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3339 - accuracy: 0.9059
# Epoch 64/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3329 - accuracy: 0.9061
# Epoch 65/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3320 - accuracy: 0.9061
# Epoch 66/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3311 - accuracy: 0.9063
# Epoch 67/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3301 - accuracy: 0.9067
# Epoch 68/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3293 - accuracy: 0.9068
# Epoch 69/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3284 - accuracy: 0.9071
# Epoch 70/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3276 - accuracy: 0.9072
# Epoch 71/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3268 - accuracy: 0.9077
# Epoch 72/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3260 - accuracy: 0.9079
# Epoch 73/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3252 - accuracy: 0.9080
# Epoch 74/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3244 - accuracy: 0.9080
# Epoch 75/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3237 - accuracy: 0.9084
# Epoch 76/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3230 - accuracy: 0.9085
# Epoch 77/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3223 - accuracy: 0.9086
# Epoch 78/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3216 - accuracy: 0.9089
# Epoch 79/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3209 - accuracy: 0.9092
# Epoch 80/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3202 - accuracy: 0.9093
# Epoch 81/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3196 - accuracy: 0.9094
# Epoch 82/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3189 - accuracy: 0.9095
# Epoch 83/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3183 - accuracy: 0.9099
# Epoch 84/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3177 - accuracy: 0.9100
# Epoch 85/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3171 - accuracy: 0.9102
# Epoch 86/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3165 - accuracy: 0.9101
# Epoch 87/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3159 - accuracy: 0.9103
# Epoch 88/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3154 - accuracy: 0.9105
# Epoch 89/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3148 - accuracy: 0.9108
# Epoch 90/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3143 - accuracy: 0.9111
# Epoch 91/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3137 - accuracy: 0.9111
# Epoch 92/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3132 - accuracy: 0.9111
# Epoch 93/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3127 - accuracy: 0.9113
# Epoch 94/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3122 - accuracy: 0.9115
# Epoch 95/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3117 - accuracy: 0.9117
# Epoch 96/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3112 - accuracy: 0.9117
# Epoch 97/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3107 - accuracy: 0.9120
# Epoch 98/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3102 - accuracy: 0.9121
# Epoch 99/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3098 - accuracy: 0.9125
# Epoch 100/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3093 - accuracy: 0.9123

# %%
score = model_bn.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 942us/step - loss: 0.2998 - accuracy: 0.9167
#
# Test accuracy: 0.916700005531311

# %%
Y_pred_bn = model_bn.predict(X_test)
y_pred_bn = np.argmax(Y_pred_bn, axis=1)
y_gt = np.argmax(Y_test, axis=1)

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_bn)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model_3")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()

# %% [markdown]
# ## Summary

# %%
score_vanilla = model.evaluate(X_test, Y_test, verbose=1)
score_bn = model_bn.evaluate(X_test, Y_test, verbose=1)

print('\n''Test accuracy of vanilla model:', score_vanilla[1])
print('\n''Test accuracy of model with Batch Norm:', score_bn[1])


plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_vanilla)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of vanilla model")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_bn)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with Batch Norm")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf
# Out:
# 313/313 [==============================] - 0s 896us/step - loss: 0.2630 - accuracy: 0.9280
# 313/313 [==============================] - 0s 893us/step - loss: 0.2998 - accuracy: 0.9167
#
# Test accuracy of vanilla model: 0.9279999732971191
#
# Test accuracy of model with Batch Norm: 0.916700005531311
# <function matplotlib.pyplot.clf()>

# %% [markdown]
# ---
#
#
# 3.   MNIST using keras with different optimizers  (20 pts)
#
#
# Refer to the lab6 and Keras tutorials to create and learn a neural network that classifies MNIST handwriting data and organize the results using keras. Use the best model you created at problem 3 on assignment6. Change the optimizer of the model to Stochastic Gradient Descent, RMSprop, Adagrad, and Adam using  keras.optimizers. Compare the results of the four models using accuracy, confusion matrix, and by plotting the loss of the models by epoch as they train.

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10

model_sgd = Sequential()
model_sgd.add(Dense(nn_hdim_1, input_dim=input_dim))
model_sgd.add(Activation('relu'))
model_sgd.add(Dense(nn_hdim_2))
model_sgd.add(Activation('relu'))
model_sgd.add(Dense(nn_hdim_3))
model_sgd.add(Activation('relu'))
model_sgd.add(Dense(output_dim))
model_sgd.add(Activation('softmax'))

model_sgd.compile(loss='categorical_crossentropy',
                  metrics=['accuracy'], optimizer='sgd')

# %%
history_sgd = model_sgd.fit(X_train, Y_train, batch_size=batch_size, 
                            epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 5ms/step - loss: 1.4804 - accuracy: 0.6617
# Epoch 2/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5744 - accuracy: 0.8646
# Epoch 3/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4075 - accuracy: 0.8929
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3459 - accuracy: 0.9055
# Epoch 5/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3107 - accuracy: 0.9134
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2862 - accuracy: 0.9201
# Epoch 7/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2672 - accuracy: 0.9251
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.9289
# Epoch 9/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2387 - accuracy: 0.9329
# Epoch 10/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2271 - accuracy: 0.9357
# Epoch 11/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2169 - accuracy: 0.9387
# Epoch 12/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2076 - accuracy: 0.9412
# Epoch 13/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1994 - accuracy: 0.9434
# Epoch 14/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1912 - accuracy: 0.9459
# Epoch 15/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1842 - accuracy: 0.9476
# Epoch 16/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1776 - accuracy: 0.9495
# Epoch 17/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1713 - accuracy: 0.9518
# Epoch 18/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1656 - accuracy: 0.9535
# Epoch 19/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1602 - accuracy: 0.9552
# Epoch 20/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1550 - accuracy: 0.9567
# Epoch 21/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1500 - accuracy: 0.9578
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1457 - accuracy: 0.9587
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1413 - accuracy: 0.9604
# Epoch 24/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1370 - accuracy: 0.9615
# Epoch 25/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1331 - accuracy: 0.9624
# Epoch 26/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1294 - accuracy: 0.9633
# Epoch 27/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1260 - accuracy: 0.9652
# Epoch 28/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1224 - accuracy: 0.9653
# Epoch 29/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1194 - accuracy: 0.9664
# Epoch 30/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1161 - accuracy: 0.9673
# Epoch 31/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1134 - accuracy: 0.9683
# Epoch 32/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1104 - accuracy: 0.9693
# Epoch 33/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1076 - accuracy: 0.9702
# Epoch 34/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1049 - accuracy: 0.9708
# Epoch 35/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1024 - accuracy: 0.9718
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1001 - accuracy: 0.9720
# Epoch 37/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0976 - accuracy: 0.9732
# Epoch 38/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0954 - accuracy: 0.9734
# Epoch 39/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0931 - accuracy: 0.9744
# Epoch 40/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0910 - accuracy: 0.9750
# Epoch 41/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0891 - accuracy: 0.9757
# Epoch 42/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0869 - accuracy: 0.9765
# Epoch 43/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0850 - accuracy: 0.9768
# Epoch 44/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0832 - accuracy: 0.9773
# Epoch 45/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0813 - accuracy: 0.9781
# Epoch 46/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0796 - accuracy: 0.9784
# Epoch 47/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0778 - accuracy: 0.9790
# Epoch 48/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0762 - accuracy: 0.9792
# Epoch 49/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0746 - accuracy: 0.9797
# Epoch 50/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0731 - accuracy: 0.9801
# Epoch 51/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0715 - accuracy: 0.9811
# Epoch 52/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0700 - accuracy: 0.9812
# Epoch 53/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0686 - accuracy: 0.9815
# Epoch 54/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0672 - accuracy: 0.9818
# Epoch 55/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0661 - accuracy: 0.9821
# Epoch 56/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0645 - accuracy: 0.9828
# Epoch 57/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0633 - accuracy: 0.9831
# Epoch 58/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0620 - accuracy: 0.9835
# Epoch 59/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0608 - accuracy: 0.9838
# Epoch 60/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0596 - accuracy: 0.9842
# Epoch 61/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0584 - accuracy: 0.9845
# Epoch 62/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0571 - accuracy: 0.9852
# Epoch 63/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0561 - accuracy: 0.9851
# Epoch 64/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0551 - accuracy: 0.9854
# Epoch 65/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0540 - accuracy: 0.9859
# Epoch 66/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0530 - accuracy: 0.9862
# Epoch 67/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0519 - accuracy: 0.9866
# Epoch 68/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0511 - accuracy: 0.9869
# Epoch 69/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0499 - accuracy: 0.9872
# Epoch 70/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0489 - accuracy: 0.9874
# Epoch 71/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0482 - accuracy: 0.9877
# Epoch 72/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0473 - accuracy: 0.9880
# Epoch 73/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0464 - accuracy: 0.9884
# Epoch 74/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0456 - accuracy: 0.9887
# Epoch 75/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0447 - accuracy: 0.9888
# Epoch 76/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0439 - accuracy: 0.9889
# Epoch 77/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0430 - accuracy: 0.9891
# Epoch 78/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0422 - accuracy: 0.9898
# Epoch 79/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0415 - accuracy: 0.9899
# Epoch 80/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0407 - accuracy: 0.9899
# Epoch 81/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0400 - accuracy: 0.9901
# Epoch 82/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0392 - accuracy: 0.9904
# Epoch 83/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0386 - accuracy: 0.9907
# Epoch 84/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0379 - accuracy: 0.9910
# Epoch 85/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0372 - accuracy: 0.9909
# Epoch 86/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0365 - accuracy: 0.9914
# Epoch 87/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0359 - accuracy: 0.9912
# Epoch 88/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - accuracy: 0.9913
# Epoch 89/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0346 - accuracy: 0.9919
# Epoch 90/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0340 - accuracy: 0.9918
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0333 - accuracy: 0.9920
# Epoch 92/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0327 - accuracy: 0.9924
# Epoch 93/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0322 - accuracy: 0.9924
# Epoch 94/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9929
# Epoch 95/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0310 - accuracy: 0.9932
# Epoch 96/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0305 - accuracy: 0.9930
# Epoch 97/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0298 - accuracy: 0.9934
# Epoch 98/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0295 - accuracy: 0.9934
# Epoch 99/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0289 - accuracy: 0.9934
# Epoch 100/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0284 - accuracy: 0.9936

# %%
score = model_sgd.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 869us/step - loss: 0.0700 - accuracy: 0.9783
#
# Test accuracy: 0.9782999753952026

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10

model_rmsprop = Sequential()
model_rmsprop.add(Dense(nn_hdim_1, input_dim=input_dim))
model_rmsprop.add(Activation('relu'))
model_rmsprop.add(Dense(nn_hdim_2))
model_rmsprop.add(Activation('relu'))
model_rmsprop.add(Dense(nn_hdim_3))
model_rmsprop.add(Activation('relu'))
model_rmsprop.add(Dense(output_dim))
model_rmsprop.add(Activation('softmax'))

model_rmsprop.compile(loss='categorical_crossentropy', 
                      metrics=['accuracy'], optimizer='rmsprop')

# %%
history_rmsprop = model_rmsprop.fit(X_train, Y_train, batch_size=batch_size, 
                                    epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2852 - accuracy: 0.9105
# Epoch 2/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0916 - accuracy: 0.9710
# Epoch 3/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0571 - accuracy: 0.9822
# Epoch 4/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0408 - accuracy: 0.9872
# Epoch 5/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0318 - accuracy: 0.9904
# Epoch 6/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0244 - accuracy: 0.9926
# Epoch 7/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0200 - accuracy: 0.9941
# Epoch 8/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0175 - accuracy: 0.9949
# Epoch 9/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0158 - accuracy: 0.9952
# Epoch 10/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0134 - accuracy: 0.9961
# Epoch 11/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0117 - accuracy: 0.9964
# Epoch 12/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9970
# Epoch 13/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9972
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9970
# Epoch 15/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9975
# Epoch 16/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9980
# Epoch 17/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9977
# Epoch 18/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9980
# Epoch 19/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0064 - accuracy: 0.9984
# Epoch 20/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9978
# Epoch 21/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 22/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9984
# Epoch 23/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9982
# Epoch 24/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 25/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 26/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9985
# Epoch 27/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0069 - accuracy: 0.9983
# Epoch 28/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9988
# Epoch 29/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 30/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 31/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9991
# Epoch 32/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 33/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - accuracy: 0.9991
# Epoch 34/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 35/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 36/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0056 - accuracy: 0.9990
# Epoch 37/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0040 - accuracy: 0.9992
# Epoch 38/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 39/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9992
# Epoch 40/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 41/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 42/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0035 - accuracy: 0.9992
# Epoch 43/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9991
# Epoch 44/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9992
# Epoch 45/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9992
# Epoch 46/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9992
# Epoch 47/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 48/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 49/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 50/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0038 - accuracy: 0.9994
# Epoch 51/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9993
# Epoch 52/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 53/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 54/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9992
# Epoch 55/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 56/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 57/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 58/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - accuracy: 0.9994
# Epoch 59/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9991
# Epoch 60/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9991
# Epoch 61/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9991
# Epoch 62/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 63/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 64/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 65/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9994
# Epoch 66/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0044 - accuracy: 0.9994
# Epoch 67/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9993
# Epoch 68/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0029 - accuracy: 0.9996
# Epoch 69/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0036 - accuracy: 0.9994
# Epoch 70/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0028 - accuracy: 0.9996
# Epoch 71/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 72/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 73/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 74/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0043 - accuracy: 0.9993
# Epoch 75/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0021 - accuracy: 0.9997
# Epoch 76/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 77/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0026 - accuracy: 0.9997
# Epoch 78/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 79/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9996
# Epoch 80/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0031 - accuracy: 0.9995
# Epoch 81/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 82/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0030 - accuracy: 0.9997
# Epoch 83/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0032 - accuracy: 0.9996
# Epoch 84/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0027 - accuracy: 0.9997
# Epoch 85/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 86/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0034 - accuracy: 0.9996
# Epoch 87/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0043 - accuracy: 0.9994
# Epoch 88/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 89/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0026 - accuracy: 0.9998
# Epoch 90/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0032 - accuracy: 0.9996
# Epoch 91/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0038 - accuracy: 0.9996
# Epoch 92/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0024 - accuracy: 0.9997
# Epoch 93/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0034 - accuracy: 0.9995
# Epoch 94/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0035 - accuracy: 0.9996
# Epoch 95/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0016 - accuracy: 0.9997
# Epoch 96/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0029 - accuracy: 0.9998
# Epoch 97/100
# 235/235 [==============================] - 2s 8ms/step - loss: 3.5103e-04 - accuracy: 0.9999
# Epoch 98/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0020 - accuracy: 0.9997
# Epoch 99/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0028 - accuracy: 0.9997
# Epoch 100/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0039 - accuracy: 0.9994

# %%
score = model_rmsprop.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 925us/step - loss: 0.3751 - accuracy: 0.9851
#
# Test accuracy: 0.9850999712944031

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10

model_adagrad = Sequential()
model_adagrad.add(Dense(nn_hdim_1, input_dim=input_dim))
model_adagrad.add(Activation('relu'))
model_adagrad.add(Dense(nn_hdim_2))
model_adagrad.add(Activation('relu'))
model_adagrad.add(Dense(nn_hdim_3))
model_adagrad.add(Activation('relu'))
model_adagrad.add(Dense(output_dim))
model_adagrad.add(Activation('softmax'))

model_adagrad.compile(loss='categorical_crossentropy', 
                      metrics=['accuracy'], optimizer='adagrad')

# %%
history_adagrad = model_adagrad.fit(X_train, Y_train, batch_size=batch_size, 
                                    epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.0560 - accuracy: 0.4674
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.4359 - accuracy: 0.7485
# Epoch 3/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.9619 - accuracy: 0.8189
# Epoch 4/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.7149 - accuracy: 0.8488
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5868 - accuracy: 0.8654
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5120 - accuracy: 0.8758
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4631 - accuracy: 0.8838
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4287 - accuracy: 0.8892
# Epoch 9/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4030 - accuracy: 0.8936
# Epoch 10/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3828 - accuracy: 0.8970
# Epoch 11/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3664 - accuracy: 0.9000
# Epoch 12/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3529 - accuracy: 0.9029
# Epoch 13/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3413 - accuracy: 0.9053
# Epoch 14/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3312 - accuracy: 0.9077
# Epoch 15/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3223 - accuracy: 0.9094
# Epoch 16/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3144 - accuracy: 0.9117
# Epoch 17/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3071 - accuracy: 0.9137
# Epoch 18/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3006 - accuracy: 0.9155
# Epoch 19/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2945 - accuracy: 0.9171
# Epoch 20/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2890 - accuracy: 0.9186
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2838 - accuracy: 0.9202
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2789 - accuracy: 0.9213
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2743 - accuracy: 0.9229
# Epoch 24/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2699 - accuracy: 0.9241
# Epoch 25/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2658 - accuracy: 0.9247
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2620 - accuracy: 0.9263
# Epoch 27/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2581 - accuracy: 0.9271
# Epoch 28/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2545 - accuracy: 0.9281
# Epoch 29/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2512 - accuracy: 0.9291
# Epoch 30/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2478 - accuracy: 0.9299
# Epoch 31/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2447 - accuracy: 0.9307
# Epoch 32/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2416 - accuracy: 0.9317
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2386 - accuracy: 0.9330
# Epoch 34/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2358 - accuracy: 0.9336
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2330 - accuracy: 0.9344
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2303 - accuracy: 0.9352
# Epoch 37/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2277 - accuracy: 0.9356
# Epoch 38/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2252 - accuracy: 0.9364
# Epoch 39/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2227 - accuracy: 0.9373
# Epoch 40/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2202 - accuracy: 0.9378
# Epoch 41/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2180 - accuracy: 0.9386
# Epoch 42/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2156 - accuracy: 0.9392
# Epoch 43/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2134 - accuracy: 0.9400
# Epoch 44/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2113 - accuracy: 0.9405
# Epoch 45/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2091 - accuracy: 0.9413
# Epoch 46/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2071 - accuracy: 0.9418
# Epoch 47/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2051 - accuracy: 0.9429
# Epoch 48/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2030 - accuracy: 0.9431
# Epoch 49/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2010 - accuracy: 0.9437
# Epoch 50/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1991 - accuracy: 0.9442
# Epoch 51/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1973 - accuracy: 0.9449
# Epoch 52/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1955 - accuracy: 0.9456
# Epoch 53/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1937 - accuracy: 0.9460
# Epoch 54/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1919 - accuracy: 0.9463
# Epoch 55/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1901 - accuracy: 0.9469
# Epoch 56/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1885 - accuracy: 0.9470
# Epoch 57/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1869 - accuracy: 0.9476
# Epoch 58/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1853 - accuracy: 0.9481
# Epoch 59/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1836 - accuracy: 0.9488
# Epoch 60/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1821 - accuracy: 0.9489
# Epoch 61/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1805 - accuracy: 0.9496
# Epoch 62/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1790 - accuracy: 0.9499
# Epoch 63/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1775 - accuracy: 0.9506
# Epoch 64/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1760 - accuracy: 0.9509
# Epoch 65/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1745 - accuracy: 0.9513
# Epoch 66/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1731 - accuracy: 0.9514
# Epoch 67/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1716 - accuracy: 0.9519
# Epoch 68/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1703 - accuracy: 0.9525
# Epoch 69/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1689 - accuracy: 0.9527
# Epoch 70/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1675 - accuracy: 0.9531
# Epoch 71/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1663 - accuracy: 0.9537
# Epoch 72/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1649 - accuracy: 0.9539
# Epoch 73/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1637 - accuracy: 0.9544
# Epoch 74/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1624 - accuracy: 0.9546
# Epoch 75/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1611 - accuracy: 0.9550
# Epoch 76/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1599 - accuracy: 0.9554
# Epoch 77/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1587 - accuracy: 0.9559
# Epoch 78/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1575 - accuracy: 0.9561
# Epoch 79/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1563 - accuracy: 0.9563
# Epoch 80/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1552 - accuracy: 0.9568
# Epoch 81/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1540 - accuracy: 0.9571
# Epoch 82/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1529 - accuracy: 0.9574
# Epoch 83/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1518 - accuracy: 0.9578
# Epoch 84/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1507 - accuracy: 0.9582
# Epoch 85/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1496 - accuracy: 0.9582
# Epoch 86/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1486 - accuracy: 0.9585
# Epoch 87/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1474 - accuracy: 0.9589
# Epoch 88/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1465 - accuracy: 0.9594
# Epoch 89/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1454 - accuracy: 0.9597
# Epoch 90/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1444 - accuracy: 0.9600
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1434 - accuracy: 0.9602
# Epoch 92/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1425 - accuracy: 0.9606
# Epoch 93/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1415 - accuracy: 0.9607
# Epoch 94/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1405 - accuracy: 0.9611
# Epoch 95/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1395 - accuracy: 0.9613
# Epoch 96/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1386 - accuracy: 0.9618
# Epoch 97/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1376 - accuracy: 0.9620
# Epoch 98/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1368 - accuracy: 0.9623
# Epoch 99/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1359 - accuracy: 0.9625
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1350 - accuracy: 0.9630

# %%
score = model_adagrad.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 939us/step - loss: 0.1436 - accuracy: 0.9575
#
# Test accuracy: 0.9574999809265137

# %%
input_dim=784
nn_hdim_1 = 1024
nn_hdim_2 = 512
nn_hdim_3 = 128
output_dim = 10

model_adam = Sequential()
model_adam.add(Dense(nn_hdim_1, input_dim=input_dim))
model_adam.add(Activation('relu'))
model_adam.add(Dense(nn_hdim_2))
model_adam.add(Activation('relu'))
model_adam.add(Dense(nn_hdim_3))
model_adam.add(Activation('relu'))
model_adam.add(Dense(output_dim))
model_adam.add(Activation('softmax'))

model_adam.compile(loss='categorical_crossentropy', 
                   metrics=['accuracy'], optimizer='adam')

# %%
history_adam = model_adam.fit(X_train, Y_train, batch_size=batch_size, 
                              epochs=epochs, verbose=1)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2334 - accuracy: 0.9305
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0764 - accuracy: 0.9765
# Epoch 3/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0487 - accuracy: 0.9849
# Epoch 4/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0351 - accuracy: 0.9889
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0278 - accuracy: 0.9908
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0205 - accuracy: 0.9934
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0178 - accuracy: 0.9940
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - accuracy: 0.9944
# Epoch 9/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0163 - accuracy: 0.9944
# Epoch 10/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0143 - accuracy: 0.9951
# Epoch 11/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0143 - accuracy: 0.9955
# Epoch 12/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0105 - accuracy: 0.9965
# Epoch 13/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 14/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - accuracy: 0.9963
# Epoch 15/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0117 - accuracy: 0.9959
# Epoch 16/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0075 - accuracy: 0.9976
# Epoch 17/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0100 - accuracy: 0.9964
# Epoch 18/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0075 - accuracy: 0.9974
# Epoch 19/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0077 - accuracy: 0.9974
# Epoch 20/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0071 - accuracy: 0.9976
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 24/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0093 - accuracy: 0.9972
# Epoch 25/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0062 - accuracy: 0.9979
# Epoch 27/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 0.9979
# Epoch 28/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 29/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0060 - accuracy: 0.9982
# Epoch 30/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.9983
# Epoch 31/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0061 - accuracy: 0.9979
# Epoch 32/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 34/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0061 - accuracy: 0.9980
# Epoch 37/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0067 - accuracy: 0.9980
# Epoch 38/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 39/100
# 235/235 [==============================] - 2s 7ms/step - loss: 9.3671e-04 - accuracy: 0.9997
# Epoch 40/100
# 235/235 [==============================] - 2s 6ms/step - loss: 8.8878e-04 - accuracy: 0.9997
# Epoch 41/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0078 - accuracy: 0.9978
# Epoch 42/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 43/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 44/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 45/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 46/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 47/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 48/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 49/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 50/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 51/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 52/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 53/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.9982
# Epoch 54/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 55/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 56/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 57/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 58/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0014 - accuracy: 0.9997
# Epoch 59/100
# 235/235 [==============================] - 1s 6ms/step - loss: 6.6019e-04 - accuracy: 0.9998
# Epoch 60/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 61/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 62/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 63/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 64/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 65/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 66/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 67/100
# 235/235 [==============================] - 1s 6ms/step - loss: 4.8885e-05 - accuracy: 1.0000
# Epoch 68/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.5004e-05 - accuracy: 1.0000
# Epoch 69/100
# 235/235 [==============================] - 1s 6ms/step - loss: 5.6062e-06 - accuracy: 1.0000
# Epoch 70/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.9181e-06 - accuracy: 1.0000
# Epoch 71/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.7571e-06 - accuracy: 1.0000
# Epoch 72/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.1762e-06 - accuracy: 1.0000
# Epoch 73/100
# 235/235 [==============================] - 2s 6ms/step - loss: 8.4447e-07 - accuracy: 1.0000
# Epoch 74/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0116 - accuracy: 0.9968
# Epoch 75/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0091 - accuracy: 0.9974
# Epoch 76/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 77/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 78/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 79/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 80/100
# 235/235 [==============================] - 1s 6ms/step - loss: 8.2118e-05 - accuracy: 1.0000
# Epoch 81/100
# 235/235 [==============================] - 1s 6ms/step - loss: 6.3542e-06 - accuracy: 1.0000
# Epoch 82/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.0041e-06 - accuracy: 1.0000
# Epoch 83/100
# 235/235 [==============================] - 1s 6ms/step - loss: 9.4531e-07 - accuracy: 1.0000
# Epoch 84/100
# 235/235 [==============================] - 1s 6ms/step - loss: 5.7537e-07 - accuracy: 1.0000
# Epoch 85/100
# 235/235 [==============================] - 1s 6ms/step - loss: 3.9496e-07 - accuracy: 1.0000
# Epoch 86/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.8619e-07 - accuracy: 1.0000
# Epoch 87/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.1588e-07 - accuracy: 1.0000
# Epoch 88/100
# 235/235 [==============================] - 2s 7ms/step - loss: 1.6477e-07 - accuracy: 1.0000
# Epoch 89/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.2860e-07 - accuracy: 1.0000
# Epoch 90/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.0077e-07 - accuracy: 1.0000
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 8.0111e-08 - accuracy: 1.0000
# Epoch 92/100
# 235/235 [==============================] - 1s 6ms/step - loss: 6.4503e-08 - accuracy: 1.0000
# Epoch 93/100
# 235/235 [==============================] - 1s 6ms/step - loss: 5.2112e-08 - accuracy: 1.0000
# Epoch 94/100
# 235/235 [==============================] - 2s 6ms/step - loss: 4.2502e-08 - accuracy: 1.0000
# Epoch 95/100
# 235/235 [==============================] - 2s 6ms/step - loss: 3.4849e-08 - accuracy: 1.0000
# Epoch 96/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.8813e-08 - accuracy: 1.0000
# Epoch 97/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.4273e-08 - accuracy: 1.0000
# Epoch 98/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.0719e-08 - accuracy: 1.0000
# Epoch 99/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.7794e-08 - accuracy: 1.0000
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 1.5402e-08 - accuracy: 1.0000

# %%
score = model_adam.evaluate(X_test, Y_test, verbose=1)
print('\n''Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 957us/step - loss: 0.1511 - accuracy: 0.9861
#
# Test accuracy: 0.9861000180244446

# %% [markdown]
# ## Summary

# %%
score_sgd = model_sgd.evaluate(X_test, Y_test, verbose=1)
score_rmsprop = model_rmsprop.evaluate(X_test, Y_test, verbose=1)
score_adagrad = model_adagrad.evaluate(X_test, Y_test, verbose=1)
score_adam = model_adam.evaluate(X_test, Y_test, verbose=1)

print("Accuracies of four models using different optimizers")
print('\n''Test accuracy of model with sgd', score_sgd[1])
print('\n''Test accuracy of model with rmsprop:', score_rmsprop[1])
print('\n''Test accuracy of model with adagrad:', score_adagrad[1])
print('\n''Test accuracy of model with adam:', score_adam[1])
# Out:
# 313/313 [==============================] - 0s 922us/step - loss: 0.0700 - accuracy: 0.9783
# 313/313 [==============================] - 0s 927us/step - loss: 0.3751 - accuracy: 0.9851
# 313/313 [==============================] - 0s 905us/step - loss: 0.1436 - accuracy: 0.9575
# 313/313 [==============================] - 0s 946us/step - loss: 0.1511 - accuracy: 0.9861
# Accuracies of four models using different optimizers
#
# Test accuracy of model with sgd 0.9782999753952026
#
# Test accuracy of model with rmsprop: 0.9850999712944031
#
# Test accuracy of model with adagrad: 0.9574999809265137
#
# Test accuracy of model with adam: 0.9861000180244446

# %%
y_loss_sgd = history_sgd.history['loss']
y_loss_rmsprop = history_rmsprop.history['loss']
y_loss_adagrad = history_adagrad.history['loss']
y_loss_adam = history_adam.history['loss']
x_len = np.arange(len(y_loss_sgd))
plt.figure(figsize=(8, 8))
plt.plot(x_len, y_loss_sgd, label='sgd')
plt.plot(x_len, y_loss_rmsprop, label='rmsprop')
plt.plot(x_len, y_loss_adagrad, label='adagrad')
plt.plot(x_len, y_loss_adam, label='adam')
plt.legend()
plt.title('loss-epoch graph')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
Y_pred_sgd = model_sgd.predict(X_test)
y_pred_sgd = np.argmax(Y_pred_sgd, axis=1)
Y_pred_rmsprop = model_rmsprop.predict(X_test)
y_pred_rmsprop = np.argmax(Y_pred_rmsprop, axis=1)
Y_pred_adagrad = model_adagrad.predict(X_test)
y_pred_adagrad = np.argmax(Y_pred_adagrad, axis=1)
Y_pred_adam = model_adam.predict(X_test)
y_pred_adam = np.argmax(Y_pred_adam, axis=1)

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_sgd)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with SGD")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_rmsprop)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with RMSprop")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_adagrad)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with ADAGRAD")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf

plt.figure(figsize=(8,8))
cm = confusion_matrix(y_gt, y_pred_adam)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix of model with ADAM")
plt.colorbar()
tick_marks = np.arange(10)
plt.xticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'], rotation=45)
plt.yticks(tick_marks, ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])
thresh = cm.max()/2.
normalize = False
fmt = '.2f' if normalize else 'd'
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j,i, format(cm[i,j], fmt), horizontalalignment="center", color="white" if cm[i,j] > thresh else "black")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.clf
# Out:
# <function matplotlib.pyplot.clf()>
